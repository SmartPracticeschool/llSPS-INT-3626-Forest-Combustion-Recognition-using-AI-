# %% [markdown]
# # video processing main

# %%
import cv2
#import facevec
import numpy as np
import smtplib
from keras.preprocessing import image 
from keras.models  import load_model

model = load_model('forest.h5') 
video = cv2.VideoCapture(0)
name = ['forest','with fire']
    
while(1):
    success, frame = video.read()
    cv2.imwrite("image.jpg",frame)
    img = image.load_img("image.jpg",target_size = (64,64))
    x  = image.img_to_array(img)
    x = np.expand_dims(x,axis = 0)
    pred = model.predict_classes(x)
    p = pred[0][0]
    print(pred)
    cv2.putText(frame, "predicted  class = "+str(name[p]), (100,100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,0), 1)
    
    
    pred = model.predict_classes(x)
    if pred[0][0]==1:
        gmail_user = 's.2016chandana'   #email id without @gmail.com
        gmail_password = 'SonyBittu*22'        #email passwrod
        #email properties
        sent_from = gmail_user
        to = ['s.2016chandana@gmail.com']
        subject = 'Alert'
        email_text = """Alert for Fire Detection, stay alert"""
        server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
        server.ehlo()
        server.login(gmail_user, gmail_password)
        server.sendmail(sent_from, to, email_text)
        server.close()
        print('Fire Detected')
        print ('Email sent!')
        #break
    else:
        print("no danger")
       #break
    #cv2.putText(frame, "The animal is "+list(l.keys())[list(l.values()).index(p[0])], (200,200), cv2.FONT_HERSHEY_PLAIN, (1.5), (0,0,0), (1))
    cv2.imshow("image",frame)
   
    if cv2.waitKey(1) & 0xFF == ord('a'): 
        break

video.release()
cv2.destroyAllWindows()
# Out:
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[0]]
# no danger
# [[1]]
# Fire Detected
# Email sent!
